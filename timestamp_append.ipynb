# %%
# %python
import os
import time
# Path to the file/directory
path = "/mnt/amerentst/output/"

for file_item in os.listdir(path):
  print(file_item)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">FileNotFoundError</span>                         Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-2745774801820597&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-intense-fg ansi-bold">      4</span> path <span class="ansi-blue-fg">=</span> <span class="ansi-blue-fg">&#34;/mnt/amerentst/output/&#34;</span>
# <span class="ansi-green-intense-fg ansi-bold">      5</span>
# <span class="ansi-green-fg">----&gt; 6</span><span class="ansi-red-fg"> </span><span class="ansi-green-fg">for</span> file_item <span class="ansi-green-fg">in</span> os<span class="ansi-blue-fg">.</span>listdir<span class="ansi-blue-fg">(</span>path<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-intense-fg ansi-bold">      7</span>   print<span class="ansi-blue-fg">(</span>file_item<span class="ansi-blue-fg">)</span>
#
# <span class="ansi-red-fg">FileNotFoundError</span>: [Errno 2] No such file or directory: &#39;/mnt/amerentst/output/&#39;</div>

# %%
dbutils.fs.ls("/mnt/amerentst/output/")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[8]: [FileInfo(path=&#39;dbfs:/mnt/amerentst/output/_delta_log/&#39;, name=&#39;_delta_log/&#39;, size=0)]</div>

# %%
access_key = 'AKIA6KZQ3UPJ5KCTJAHD'
secret_key = 'siBysFH1eJlCV5LXvqLmNyUa2qJ/SJ2h1DH3cG3i'
encoded_secret_key = secret_key.replace("/", "%2F")
aws_bucket_name = "shreyatest"
mount_name = "amerentst"
dbutils.fs.mount("s3a://%s:%s@%s" % (access_key, encoded_secret_key, aws_bucket_name), "/mnt/%s" % mount_name)
dbutils.fs.ls("/mnt/amerentst/")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">ExecutionError</span>                            Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-2745774801820599&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-intense-fg ansi-bold">      4</span> aws_bucket_name <span class="ansi-blue-fg">=</span> <span class="ansi-blue-fg">&#34;shreyatest&#34;</span>
# <span class="ansi-green-intense-fg ansi-bold">      5</span> mount_name <span class="ansi-blue-fg">=</span> <span class="ansi-blue-fg">&#34;amerentst&#34;</span>
# <span class="ansi-green-fg">----&gt; 6</span><span class="ansi-red-fg"> </span>dbutils<span class="ansi-blue-fg">.</span>fs<span class="ansi-blue-fg">.</span>mount<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;s3a://%s:%s@%s&#34;</span> <span class="ansi-blue-fg">%</span> <span class="ansi-blue-fg">(</span>access_key<span class="ansi-blue-fg">,</span> encoded_secret_key<span class="ansi-blue-fg">,</span> aws_bucket_name<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">,</span> <span class="ansi-blue-fg">&#34;/mnt/%s&#34;</span> <span class="ansi-blue-fg">%</span> mount_name<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">      7</span> dbutils<span class="ansi-blue-fg">.</span>fs<span class="ansi-blue-fg">.</span>ls<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;/mnt/amerentst/&#34;</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-green-fg">/databricks/python_shell/dbruntime/dbutils.py</span> in <span class="ansi-cyan-fg">f_with_exception_handling</span><span class="ansi-blue-fg">(*args, **kwargs)</span>
# <span class="ansi-green-intense-fg ansi-bold">    328</span>                     exc<span class="ansi-blue-fg">.</span>__context__ <span class="ansi-blue-fg">=</span> <span class="ansi-green-fg">None</span>
# <span class="ansi-green-intense-fg ansi-bold">    329</span>                     exc<span class="ansi-blue-fg">.</span>__cause__ <span class="ansi-blue-fg">=</span> <span class="ansi-green-fg">None</span>
# <span class="ansi-green-fg">--&gt; 330</span><span class="ansi-red-fg">                     </span><span class="ansi-green-fg">raise</span> exc
# <span class="ansi-green-intense-fg ansi-bold">    331</span>             <span class="ansi-green-fg">return</span> f_with_exception_handling
# <span class="ansi-green-intense-fg ansi-bold">    332</span>
#
# <span class="ansi-red-fg">ExecutionError</span>: An error occurred while calling o274.mount.
# : java.rmi.RemoteException: java.lang.IllegalArgumentException: requirement failed: Directory already mounted: /mnt/amerentst; nested exception is:
# 	java.lang.IllegalArgumentException: requirement failed: Directory already mounted: /mnt/amerentst
# 	at com.databricks.backend.daemon.data.client.DbfsClient.send0(DbfsClient.scala:128)
# 	at com.databricks.backend.daemon.data.client.DbfsClient.sendIdempotent(DbfsClient.scala:68)
# 	at com.databricks.backend.daemon.dbutils.DBUtilsCore.mount(DBUtilsCore.scala:739)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at py4j.reflection.MethodInvoker.invoke(MethodInvoker.java:244)
# 	at py4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:380)
# 	at py4j.Gateway.invoke(Gateway.java:295)
# 	at py4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:132)
# 	at py4j.commands.CallCommand.execute(CallCommand.java:79)
# 	at py4j.GatewayConnection.run(GatewayConnection.java:251)
# 	at java.lang.Thread.run(Thread.java:748)
# Caused by: java.lang.IllegalArgumentException: requirement failed: Directory already mounted: /mnt/amerentst
# 	at scala.Predef$.require(Predef.scala:281)
# 	at com.databricks.backend.daemon.data.server.DefaultMetadataManager.$anonfun$insertMount$1(MetadataManager.scala:417)
# 	at com.databricks.backend.daemon.data.server.DefaultMetadataManager.$anonfun$modifyAndVerify$1(MetadataManager.scala:713)
# 	at com.databricks.backend.daemon.data.server.DefaultMetadataManager.withRetries(MetadataManager.scala:517)
# 	at com.databricks.backend.daemon.data.server.DefaultMetadataManager.modifyAndVerify(MetadataManager.scala:702)
# 	at com.databricks.backend.daemon.data.server.DefaultMetadataManager.insertMount(MetadataManager.scala:425)
# 	at com.databricks.backend.daemon.data.server.handler.MountHandler.receive(MountHandler.scala:90)
# 	at com.databricks.backend.daemon.data.server.handler.CEMountHandler.receive(MountHandler.scala:145)
# 	at com.databricks.backend.daemon.data.server.session.SessionContext.$anonfun$queryHandlers$1(SessionContext.scala:98)
# 	at com.databricks.backend.daemon.data.server.session.SessionContext.$anonfun$queryHandlers$1$adapted(SessionContext.scala:97)
# 	at scala.collection.immutable.List.foreach(List.scala:392)
# 	at com.databricks.backend.daemon.data.server.session.SessionContext.queryHandlers(SessionContext.scala:97)
# 	at com.databricks.backend.daemon.data.server.DbfsServerBackend$$anonfun$receive$3.applyOrElse(DbfsServerBackend.scala:299)
# 	at com.databricks.backend.daemon.data.server.DbfsServerBackend$$anonfun$receive$3.applyOrElse(DbfsServerBackend.scala:258)
# 	at com.databricks.rpc.ServerBackend.$anonfun$internalReceive$2(ServerBackend.scala:54)
# 	at com.databricks.rpc.ServerBackend$$anonfun$commonReceive$1.applyOrElse(ServerBackend.scala:81)
# 	at com.databricks.rpc.ServerBackend$$anonfun$commonReceive$1.applyOrElse(ServerBackend.scala:81)
# 	at com.databricks.rpc.ServerBackend.$anonfun$internalReceive$1(ServerBackend.scala:50)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperation$4(UsageLogging.scala:434)
# 	at com.databricks.logging.UsageLogging.$anonfun$withAttributionContext$1(UsageLogging.scala:240)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:62)
# 	at com.databricks.logging.UsageLogging.withAttributionContext(UsageLogging.scala:235)
# 	at com.databricks.logging.UsageLogging.withAttributionContext$(UsageLogging.scala:232)
# 	at com.databricks.rpc.ServerBackend.withAttributionContext(ServerBackend.scala:17)
# 	at com.databricks.logging.UsageLogging.withAttributionTags(UsageLogging.scala:279)
# 	at com.databricks.logging.UsageLogging.withAttributionTags$(UsageLogging.scala:271)
# 	at com.databricks.rpc.ServerBackend.withAttributionTags(ServerBackend.scala:17)
# 	at com.databricks.logging.UsageLogging.recordOperation(UsageLogging.scala:415)
# 	at com.databricks.logging.UsageLogging.recordOperation$(UsageLogging.scala:341)
# 	at com.databricks.rpc.ServerBackend.recordOperation(ServerBackend.scala:17)
# 	at com.databricks.rpc.ServerBackend.internalReceive(ServerBackend.scala:49)
# 	at com.databricks.rpc.JettyServer$RequestManager.$anonfun$handleRPC$2(JettyServer.scala:677)
# 	at scala.util.Try$.apply(Try.scala:213)
# 	at com.databricks.rpc.JettyServer$RequestManager.handleRPC(JettyServer.scala:677)
# 	at com.databricks.rpc.JettyServer$RequestManager.handleRequestAndRespond(JettyServer.scala:599)
# 	at com.databricks.rpc.JettyServer$RequestManager.$anonfun$handleHttp$1(JettyServer.scala:353)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at com.databricks.logging.UsageLogging.$anonfun$withAttributionContext$1(UsageLogging.scala:240)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:62)
# 	at com.databricks.logging.UsageLogging.withAttributionContext(UsageLogging.scala:235)
# 	at com.databricks.logging.UsageLogging.withAttributi

# %%
dbutils.fs.ls("/mnt/amerentst/input/2021-06-07/SalesRecordsDelta.csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[10]: [FileInfo(path=&#39;dbfs:/mnt/amerentst/input/2021-06-07/SalesRecordsDelta.csv&#39;, name=&#39;SalesRecordsDelta.csv&#39;, size=519)]</div>

# %%
# %python
import boto3
s3 = boto3.connect_s3()
bucket = s3.lookup('shreyatest')
for key in bucket:
       print (key.name, key.size, key.last_modified)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">AttributeError</span>                            Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-2745774801820601&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-intense-fg ansi-bold">      1</span> <span class="ansi-green-fg">import</span> boto3
# <span class="ansi-green-fg">----&gt; 2</span><span class="ansi-red-fg"> </span>s3 <span class="ansi-blue-fg">=</span> boto3<span class="ansi-blue-fg">.</span>connect_s3<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">      3</span> bucket <span class="ansi-blue-fg">=</span> s3<span class="ansi-blue-fg">.</span>lookup<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#39;shreyatest&#39;</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">      4</span> <span class="ansi-green-fg">for</span> key <span class="ansi-green-fg">in</span> bucket<span class="ansi-blue-fg">:</span>
# <span class="ansi-green-intense-fg ansi-bold">      5</span>        print <span class="ansi-blue-fg">(</span>key<span class="ansi-blue-fg">.</span>name<span class="ansi-blue-fg">,</span> key<span class="ansi-blue-fg">.</span>size<span class="ansi-blue-fg">,</span> key<span class="ansi-blue-fg">.</span>last_modified<span class="ansi-blue-fg">)</span>
#
# <span class="ansi-red-fg">AttributeError</span>: module &#39;boto3&#39; has no attribute &#39;connect_s3&#39;</div>

# %%
#s3 = boto3.resource('s3',aws_access_key_id='AKIA6KZQ3UPJ5KCTJAHD',aws_secret_access_key= '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')
#s3 = boto3.resource('s3')

import boto3
s3 = boto3.resource('s3',aws_access_key_id='AKIA6KZQ3UPJ5KCTJAHD',aws_secret_access_key= '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')
bucket = s3.Bucket('shreyatest')
[obj.last_modified for obj in bucket.objects.all()][:10]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[72]: [datetime.datetime(2021, 6, 4, 6, 12, 55, tzinfo=tzlocal()),
#  datetime.datetime(2021, 6, 4, 6, 12, 55, tzinfo=tzlocal()),
#  datetime.datetime(2021, 6, 7, 11, 13, 25, tzinfo=tzlocal()),
#  datetime.datetime(2021, 6, 7, 11, 14, tzinfo=tzlocal()),
#  datetime.datetime(2021, 6, 8, 6, 46, 31, tzinfo=tzlocal()),
#  datetime.datetime(2021, 6, 7, 10, 55, 1, tzinfo=tzlocal()),
#  datetime.datetime(2021, 6, 7, 10, 55, 57, tzinfo=tzlocal()),
#  datetime.datetime(2021, 6, 7, 11, 4, 50, tzinfo=tzlocal()),
#  datetime.datetime(2021, 6, 7, 11, 3, 50, tzinfo=tzlocal()),
#  datetime.datetime(2021, 6, 7, 11, 12, 42, tzinfo=tzlocal())]</div>

# %%
import boto3
s3 = boto3.resource('s3')
my_bucket = s3.Bucket('shreyatest')
print(bucket.name)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">shreyatest
# </div>

# %%
import boto3

# Let's use Amazon S3
s3 = boto3.resource('s3',aws_access_key_id='AKIA6KZQ3UPJ5KCTJAHD',aws_secret_access_key= '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')

# Print out bucket names
for bucket in s3.buckets.all():
    print(bucket.name)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">adinew
# aditya081
# bu1997
# fakebucket08
# my-source-bucket-07
# my-target-bucket07
# shreyatest
# </div>

# %%
import os
import time
import boto3
s3 = boto3.resource('s3',aws_access_key_id='AKIA6KZQ3UPJ5KCTJAHD',aws_secret_access_key= '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')
my_bucket = s3.Bucket('shreyatest')
path_variable_array = []
for obj in my_bucket.objects.all():
   #print('{} , {}'.format(obj.key, obj.last_modified))
   
  path_array = obj.key.split('/')[:-1]
  path_variable = ''
  for i in path_array:
    path_variable = path_variable + i + '/'
    #print(path_variable)
  path_variable_array.append(path_variable)
  
  
print(path_variable_array)
      #+ str(obj.last_modified)
      #basetime = os.path.basetime(obj.last_modified)
      
      #if basename != '' and '.csv' in basename:
       #print(basename+'_'+str(obj.last_modified).replace(" ", "_"))
      #if basename != '' and '.json' in basename:
       # print(basename+'_'+str(obj.last_modified).replace(" ", "_"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[&#39;TestDatabricks/&#39;, &#39;TestDatabricks/&#39;, &#39;config/&#39;, &#39;config/CDC/&#39;, &#39;config/CDC/&#39;, &#39;input/&#39;, &#39;input/2021-06-06/&#39;, &#39;input/2021-06-06/&#39;, &#39;input/2021-06-07/&#39;, &#39;input/2021-06-07/&#39;, &#39;input/2021-06-10/Customers/&#39;, &#39;input/2021-06-10/Customers/&#39;, &#39;input/2021-06-10/Orders/&#39;, &#39;input/2021-06-10/Orders/&#39;, &#39;input/2021-06-11/&#39;, &#39;input/2021-06-11/CustomerDelta/&#39;, &#39;input/2021-06-11/CustomerDelta/&#39;, &#39;input/2021-06-11/OrdersDelta/&#39;, &#39;input/2021-06-11/OrdersDelta/&#39;, &#39;input/delta-poc/&#39;, &#39;input/delta-poc/db/&#39;, &#39;input/delta-poc/db/formatted/&#39;, &#39;input/delta-poc/db/formatted/public/&#39;, &#39;input/delta-poc/db/formatted/public/db_Customer_f/&#39;, &#39;input/delta-poc/db/formatted/public/db_Customer_f/_delta_log/&#39;, &#39;input/delta-poc/db/formatted/public/db_Customer_f/_delta_log/&#39;, &#39;input/delta-poc/db/formatted/public/db_Customer_f/_delta_log/&#39;, &#39;input/delta-poc/db/formatted/public/db_Customer_f/_delta_log/&#39;, &#39;input/delta-poc/db/formatted/public/db_Customer_f/_delta_log/&#39;, &#39;input/delta-poc/db/formatted/public/db_Customer_f/_delta_log/&#39;, &#39;input/delta-poc/db/formatted/public/db_Customer_f/_delta_log/&#39;, &#39;input/delta-poc/db/formatted/public/db_Customer_f/_delta_log/&#39;, &#39;input/delta-poc/db/formatted/public/db_Customer_f/&#39;, &#39;input/delta-poc/db/formatted/public/db_Customer_f/&#39;, &#39;input/delta-poc/db/formatted/public/db_Customer_f/&#39;, &#39;input/delta-poc/db/formatted/public/db_Customer_f/&#39;, &#39;input/delta-poc/db/formatted/public/db_Customer_f/&#39;, &#39;input/delta-poc/db/formatted/public/db_Customer_f/&#39;, &#39;input/delta-poc/db/formatted/public/db_Order_f/&#39;, &#39;input/delta-poc/db/formatted/public/db_Order_f/_delta_log/&#39;, &#39;input/delta-poc/db/formatted/public/db_Order_f/_delta_log/&#39;, &#39;input/delta-poc/db/formatted/public/db_Order_f/_delta_log/&#39;, &#39;input/delta-poc/db/formatted/public/db_Order_f/_delta_log/&#39;, &#39;input/delta-poc/db/formatted/public/db_Order_f/_delta_log/&#39;, &#39;input/delta-poc/db/formatted/public/db_Order_f/_delta_log/&#39;, &#39;input/delta-poc/db/formatted/public/db_Order_f/_delta_log/&#39;, &#39;input/delta-poc/db/formatted/public/db_Order_f/_delta_log/&#39;, &#39;input/delta-poc/db/formatted/public/db_Order_f/_delta_log/&#39;, &#39;input/delta-poc/db/formatted/public/db_Order_f/_delta_log/&#39;, &#39;input/delta-poc/db/formatted/public/db_Order_f/_delta_log/&#39;, &#39;input/delta-poc/db/formatted/public/db_Order_f/_delta_log/&#39;, &#39;input/delta-poc/db/formatted/public/db_Order_f/_delta_log/&#39;, &#39;input/delta-poc/db/formatted/public/db_Order_f/_delta_log/&#39;, &#39;input/delta-poc/db/formatted/public/db_Order_f/_delta_log/&#39;, &#39;input/delta-poc/db/formatted/public/db_Order_f/_delta_log/&#39;, &#39;input/delta-poc/db/formatted/public/db_Order_f/_delta_log/&#39;, &#39;input/delta-poc/db/formatted/public/db_Order_f/_delta_log/&#39;, &#39;input/delta-poc/db/formatted/public/db_Order_f/_delta_log/&#39;, &#39;input/delta-poc/db/formatted/public/db_Order_f/_delta_log/&#39;, &#39;input/delta-poc/db/formatted/public/db_Order_f/_delta_log/&#39;, &#39;input/delta-poc/db/formatted/public/db_Order_f/_delta_log/&#39;, &#39;input/delta-poc/db/formatted/public/db_Order_f/_delta_log/&#39;, &#39;input/delta-poc/db/formatted/public/db_Order_f/_delta_log/&#39;, &#39;input/delta-poc/db/formatted/public/db_Order_f/_delta_log/&#39;, &#39;input/delta-poc/db/formatted/public/db_Order_f/_delta_log/&#39;, &#39;input/delta-poc/db/formatted/public/db_Order_f/_delta_log/&#39;, &#39;input/delta-poc/db/formatted/public/db_Order_f/_delta_log/&#39;, &#39;input/delta-poc/db/formatted/public/db_Order_f/_delta_log/&#39;, &#39;input/delta-poc/db/formatted/public/db_Order_f/_delta_log/&#39;, &#39;input/delta-poc/db/formatted/public/db_Order_f/_ ...

# %%
def createDF(file_name,file_timestamp):
  df = spark.read.format()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Empty DataFrame
# Columns: []
# Index: []
# </div>

# %%
import os
basename = os.path.basename('TestDatabricks/SalesRecords.csv')
print(basename)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">SalesRecords.csv
# </div>

# %%
import os
import boto3
s3 = boto3.resource('s3',aws_access_key_id='AKIA6KZQ3UPJ5KCTJAHD',aws_secret_access_key= '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')
my_bucket = s3.Bucket('shreyatest')

def append_timestamp(timestamp):
    name, ext = os.path.splitext(basename)
    return "{name}_{timestamp}{ext}".format(name=name, timestamp=obj.last_modified, ext=ext)
  
for obj in my_bucket.objects.all():
    #print('{} , {}'.format(obj.key, obj.last_modified))
      #+ str(obj.last_modified)
      basename = os.path.basename(obj.key)
      #print(basename)
      
      
      if basename != '' and ('.csv' in basename or '.json' in basename):
       #print(basename+'_'+str(obj.last_modified).replace(" ", "_"))
         full_filename =  append_timestamp(obj.last_modified).replace(" ", "_")
         print(full_filename)
      
      #elif basename != '' and '.json' in basename:
        #print(basename+'_'+str(obj.last_modified).replace(" ", "_"))
       # full_filename =  append_timestamp(obj.last_modified)
        #print(full_filename)
        
        
      #if basename != '' and '.csv' in basename:
      #   print(basename+'_'+str(obj.last_modified).replace(" ", "_"))
      #elif basename != '' and '.json' in basename:
      #  print(basename+'_'+str(obj.last_modified).replace(" ", "_"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">SalesRecords_2021-06-04_06:12:55+00:00.csv
# SalesRecordsCDCConfig_2021-06-08_06:46:31+00:00.json
# SalesRecords_2021-06-07_11:04:50+00:00.csv
# SalesRecordsDelta_2021-06-07_11:12:42+00:00.csv
# Customer_2021-06-11_11:38:19+00:00.csv
# Orders_2021-06-11_11:54:59+00:00.csv
# CustometDelta_2021-06-11_12:04:44+00:00.csv
# OrderDelta_2021-06-11_12:00:40+00:00.csv
# 00000000000000000000_2021-06-16_12:59:46+00:00.json
# 00000000000000000001_2021-06-16_13:03:21+00:00.json
# 00000000000000000000_2021-06-16_13:11:48+00:00.json
# 00000000000000000001_2021-06-17_05:18:03+00:00.json
# 00000000000000000002_2021-06-17_05:20:16+00:00.json
# 00000000000000000003_2021-06-17_05:23:18+00:00.json
# 00000000000000000004_2021-06-17_05:24:56+00:00.json
# 00000000000000000005_2021-06-17_05:28:00+00:00.json
# 00000000000000000006_2021-06-17_05:29:47+00:00.json
# 00000000000000000007_2021-06-17_05:32:25+00:00.json
# 00000000000000000008_2021-06-17_05:35:28+00:00.json
# 00000000000000000009_2021-06-17_05:52:22+00:00.json
# 00000000000000000010_2021-06-17_05:58:46+00:00.json
# 00000000000000000011_2021-06-17_06:00:33+00:00.json
# 00000000000000000012_2021-06-17_06:07:39+00:00.json
# 00000000000000000013_2021-06-17_06:16:04+00:00.json
# 00000000000000000000_2021-06-08_10:40:54+00:00.json
# 00000000000000000001_2021-06-08_13:38:04+00:00.json
# 00000000000000000002_2021-06-08_13:39:58+00:00.json
# part-00000-tid-6287785740859178763-8afecd2c-e5f1-45bf-8947-f67c5271efd2-358-1-c000_2021-06-08_13:39:31+00:00.csv
# </div>

# %%
import os
import boto3
s3 = boto3.resource('s3',aws_access_key_id='AKIA6KZQ3UPJ5KCTJAHD',aws_secret_access_key= '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')
my_bucket = s3.Bucket('shreyatest')
  
basetimestamp_array = []
basename_array = []
for obj in my_bucket.objects.all():
    #print('{} , {}'.format(obj.key, obj.last_modified))
      #+ str(obj.last_modified)
      basetimestamp = os.path.basename(str(obj.last_modified)).replace(" ", "_")
      basename = os.path.basename(str(obj.key))
      #print(type(basetimestamp))
      if basename != '' and ('.csv' in basename or '.json' in basename):
        #print(basename+ ' ' + basetimestamp)
        basetimestamp_array.append(basetimestamp)
        basename_array.append(basename)


#print(basetimestamp_array) 
print(basename_array)


      
      #if basename != '' and ('.csv' in basename or '.json' in basename):
       #print(basename+'_'+str(obj.last_modified).replace(" ", "_"))
       #  full_filename =  append_timestamp(obj.last_modified).replace(" ", "_")
        # print(full_filename)
      
      #elif basename != '' and '.json' in basename:
        #print(basename+'_'+str(obj.last_modified).replace(" ", "_"))
       # full_filename =  append_timestamp(obj.last_modified)
        #print(full_filename)
        
        
      #if basename != '' and '.csv' in basename:
      #   print(basename+'_'+str(obj.last_modified).replace(" ", "_"))
      #elif basename != '' and '.json' in basename:
      #  print(basename+'_'+str(obj.last_modified).replace(" ", "_"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[&#39;SalesRecords.csv&#39;, &#39;SalesRecordsCDCConfig.json&#39;, &#39;SalesRecords.csv&#39;, &#39;SalesRecordsDelta.csv&#39;, &#39;Customer.csv&#39;, &#39;Orders.csv&#39;, &#39;CustometDelta.csv&#39;, &#39;OrderDelta.csv&#39;, &#39;00000000000000000000.json&#39;, &#39;00000000000000000001.json&#39;, &#39;00000000000000000000.json&#39;, &#39;00000000000000000001.json&#39;, &#39;00000000000000000002.json&#39;, &#39;00000000000000000003.json&#39;, &#39;00000000000000000004.json&#39;, &#39;00000000000000000005.json&#39;, &#39;00000000000000000006.json&#39;, &#39;00000000000000000007.json&#39;, &#39;00000000000000000008.json&#39;, &#39;00000000000000000009.json&#39;, &#39;00000000000000000010.json&#39;, &#39;00000000000000000011.json&#39;, &#39;00000000000000000012.json&#39;, &#39;00000000000000000013.json&#39;, &#39;00000000000000000000.json&#39;, &#39;00000000000000000001.json&#39;, &#39;00000000000000000002.json&#39;, &#39;part-00000-tid-6287785740859178763-8afecd2c-e5f1-45bf-8947-f67c5271efd2-358-1-c000.csv&#39;]
# </div>

# %%
from pyspark.sql.functions import lit
#df = spark.read.csv("dbfs:/mnt/amerentst/input/2021-06-07/SalesRecordsDelta.csv" %mount_name)

#for i in range(len(basename_array)):

df = spark.read.csv("dbfs:/mnt/amerentst/input/2021-06-06/SalesRecords.csv")
#print (df.head())
#df.show(5)

for i in range(len(basetimestamp_array)):
  df2 = df.withColumn("last_update_timestamp",lit(basetimestamp_array[i]))
#df2.show()
display(df2)


#TestDatabricks/SalesRecords.csv
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_c0</th><th>_c1</th><th>_c2</th><th>_c3</th><th>_c4</th><th>_c5</th><th>_c6</th><th>_c7</th><th>_c8</th><th>_c9</th><th>_c10</th><th>_c11</th><th>_c12</th><th>_c13</th><th>last_update_timestamp</th></tr></thead><tbody><tr><td>Region</td><td>Country</td><td>ItemType</td><td>SalesChannel</td><td>OrderPriority</td><td>OrderDate</td><td>OrderID</td><td>ShipDate</td><td>UnitsSold</td><td>UnitPrice</td><td>UnitCost</td><td>TotalRevenue</td><td>TotalCost</td><td>TotalProfit</td><td>2021-06-08_13:39:31+00:00</td></tr><tr><td>Australia and Oceania</td><td>Tuvalu</td><td>Baby Food</td><td>Offline</td><td>H</td><td>5/28/2010</td><td>669165933</td><td>6/27/2010</td><td>9925</td><td>255.28</td><td>159.42</td><td>2533654</td><td>1582243.5</td><td>951410.5</td><td>2021-06-08_13:39:31+00:00</td></tr><tr><td>Central America and the Caribbean</td><td>Grenada</td><td>Cereal</td><td>Online</td><td>C</td><td>8/22/2012</td><td>963881480</td><td>9/15/2012</td><td>2804</td><td>205.7</td><td>117.11</td><td>576782.8</td><td>328376.44</td><td>248406.36</td><td>2021-06-08_13:39:31+00:00</td></tr><tr><td>Europe</td><td>Russia</td><td>Office Supplies</td><td>Offline</td><td>L</td><td>5/2/2014</td><td>341417157</td><td>5/8/2014</td><td>1779</td><td>651.21</td><td>524.96</td><td>1158502.59</td><td>933903.84</td><td>224598.75</td><td>2021-06-08_13:39:31+00:00</td></tr><tr><td>Sub-Saharan Africa</td><td>
# %%
from pyspark.sql.functions import lit
#df = spark.read.csv("dbfs:/mnt/amerentst/input/2021-06-07/SalesRecordsDelta.csv" %mount_name)

#for i in range(len(basename_array)):

fixed_path = 'dbfs:/mnt/amerentst/'
#fixed_path + path_variable + basename

basetimestamp_array = []
basename_array = []
path_variable_array = []


for obj in my_bucket.objects.all():
  
  basetimestamp1 = os.path.basename(str(obj.last_modified)).replace(" ", "_")
  basename1 = os.path.basename(str(obj.key))
  
  if basename1 != '' and ('.csv' in basename1 or '.json' in basename1):
    basetimestamp_array1.append(basetimestamp1)
    basename_array1.append(basename1)
    
    path_array = obj.key.split('/')[:-1]
    path_variable = ''
    
    for i in path_array:
      path_variable = path_variable + i + '/'
      #print(path_variable)
    path_variable_array.append(path_variable)
    
    

    full_file_path = fixed_path + path_variable + basename1
    print(full_file_path)

    df = spark.read.csv(full_file_path)
    print (df.head())
    df.show(5)

    for i in range(len(basetimestamp_array1)):
      df2 = df.withColumn("last_update_timestamp",lit(basetimestamp_array1[i]))
    df2.show()
    display(df2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">dbfs:/mnt/amerentst/TestDatabricks/SalesRecords.csv
# Row(_c0=&#39;Region&#39;, _c1=&#39;Country&#39;, _c2=&#39;Item Type&#39;, _c3=&#39;Sales Channel&#39;, _c4=&#39;Order Priority&#39;, _c5=&#39;Order Date&#39;, _c6=&#39;Order ID&#39;, _c7=&#39;Ship Date&#39;, _c8=&#39;Units Sold&#39;, _c9=&#39;Unit Price&#39;, _c10=&#39;Unit Cost&#39;, _c11=&#39;Total Revenue&#39;, _c12=&#39;Total Cost&#39;, _c13=&#39;Total Profit&#39;)
# +--------------------+--------------------+---------------+-------------+--------------+----------+---------+---------+----------+----------+---------+-------------+----------+------------+
#                  _c0|                 _c1|            _c2|          _c3|           _c4|       _c5|      _c6|      _c7|       _c8|       _c9|     _c10|         _c11|      _c12|        _c13|
# +--------------------+--------------------+---------------+-------------+--------------+----------+---------+---------+----------+----------+---------+-------------+----------+------------+
#               Region|             Country|      Item Type|Sales Channel|Order Priority|Order Date| Order ID|Ship Date|Units Sold|Unit Price|Unit Cost|Total Revenue|Total Cost|Total Profit|
# Australia and Oce...|              Tuvalu|      Baby Food|      Offline|             H| 5/28/2010|669165933|6/27/2010|      9925|    255.28|   159.42|      2533654| 1582243.5|    951410.5|
# Central America a...|             Grenada|         Cereal|       Online|             C| 8/22/2012|963881480|9/15/2012|      2804|     205.7|   117.11|     576782.8| 328376.44|   248406.36|
#               Europe|              Russia|Office Supplies|      Offline|             L|  5/2/2014|341417157| 5/8/2014|      1779|    651.21|   524.96|   1158502.59| 933903.84|   224598.75|
#   Sub-Saharan Africa|Sao Tome and Prin...|         Fruits|       Online|             C| 6/20/2014|514321792| 7/5/2014|      8102|      9.33|     6.92|     75591.66|  56065.84|    19525.82|
# +--------------------+--------------------+---------------+-------------+--------------+----------+---------+---------+----------+----------+---------+-------------+----------+------------+
# only showing top 5 rows
#
# +--------------------+--------------------+---------------+-------------+--------------+----------+---------+----------+----------+----------+---------+-------------+----------+------------
td><td>2021-06-08_06:46:31+00:00</td></tr><tr><td>"OutputRootPath" : "/mnt/amerentst/output/"</td><td>2021-06-08_06:46:31+00:00</td></tr><tr><td>"delimiter" : "</td><td>2021-06-08_06:46:31+00:00</td></tr><tr><td>"changingCols" : "region</td><td>2021-06-08_06:46:31+00:00</td></tr><tr><td>"pkCols" : "orderid"</td><td>2021-06-08_06:46:31+00:00</td></tr><tr><td>"headerString" : "region</td><td>2021-06-08_06:46:31+00:00</td></tr><tr><td>"tgtHeaderString" : "region</td><td>2021-06-08_06:46:31+00:00</td></tr><tr><td>}</td><td>2021-06-08_06:46:31+00:00</td></tr></tbody></table></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">dbfs:/mnt/amerentst/input/2021-06-06/SalesRecords.csv
# Row(_c0=&#39;Region&#39;, _c1=&#39;Country&#39;, _c2=&#39;ItemType&#39;, _c3=&#39;SalesChannel&#39;, _c4=&#39;OrderPriority&#39;, _c5=&#39;OrderDate&#39;, _c6=&#39;OrderID&#39;, _c7=&#39;ShipDate&#39;, _c8=&#39;UnitsSold&#39;, _c9=&#39;UnitPrice&#39;, _c10=&#39;UnitCost&#39;, _c11=&#39;TotalRevenue&#39;, _c12=&#39;TotalCost&#39;, _c13=&#39;TotalProfit&#39;)
# +--------------------+--------------------+---------------+------------+-------------+---------+---------+---------+---------+---------+--------+------------+---------+-----------+
#                  _c0|                 _c1|            _c2|         _c3|          _c4|      _c5|      _c6|      _c7|      _c8|      _c9|    _c10|        _c11|     _c12|       _c13|
# +--------------------+--------------------+---------------+------------+-------------+---------+---------+---------+---------+---------+--------+------------+---------+-----------+
#               Region|             Country|       ItemType|SalesChannel|OrderPriority|OrderDate|  OrderID| ShipDate|UnitsSold|UnitPrice|UnitCost|TotalRevenue|TotalCost|TotalProfit|
# Australia and Oce...|              Tuvalu|      Baby Food|     Offline|            H|5/28/2010|669165933|6/27/2010|     9925|   255.28|  159.42|     2533654|1582243.5|   951410.5|
# Central America a...|             Grenada|         Cereal|      Online|            C|8/22/2012|963881480|9/15/2012|     2804|    205.7|  117.11|    576782.8|328376.44|  248406.36|
#               Europe|              Russia|Office Supplies|     Offline|            L| 5/2/2014|341417157| 5/8/2014|     1779|   651.21|  524.96|  1158502.59|933903.84|  224598.75|
#   Sub-Saharan Africa|Sao Tome and Prin...|         Fruits|      Online|            C|6/20/2014|514321792| 7/5/2014|     8102|     9.33|    6.92|    75591.66| 56065.84|   19525.82|
# +--------------------+--------------------+---------------+------------+-------------+---------+---------+---------+---------+---------+--------+------------+---------+-----------+
# only showing top 5 rows
#
# +--------------------+--------------------+---------------+------------+-------------+----------+---------+----------+---------+---------+--------+------------+----------+-----------+---------------------+
#                  _c0|                 _c1|            _c2|         _c3|          _c4|       _c5|      _c6|       _c7|      _c8|      _c9|    _c10|        _c11|      _c12|       _c13|last_update_timestamp|
# +--------------------+--------------------+---------------+------------+-------------+----------+---------+----------+---------+---------+--------+------------+----------+-----------+---------------------+
#               Region|             Country|       ItemType|SalesChannel|OrderPriority| OrderDate|  OrderID|  ShipDate|UnitsSold|UnitPrice|UnitCost|TotalRevenue| TotalCost|TotalProfit| 2021-06-07_11:04:...|
# Australia and Oce...|              Tuvalu|      Baby Food|     Offline|            H| 5/28/2010|669165933| 6/27/2010|     9925|   255.28|  159.42|     2533654| 1582243.5|   951410.5| 2021-06-07_11:04:...|
# Central America a...|             Grenada|         Cereal|      Online|            C| 8/22/2012|963881480| 9/15/2012|     2804|    205.7|  117.11|    576782.8| 328376.44|  248406.36| 2021-06-07_11:04:...|
td><td>2021-06-07_11:04:50+00:00</td></tr><tr><td>Asia</td><td>Kyrgyzstan</td><td>Vegetables</td><td>Online</td><td>H</td><td>6/24/2011</td><td>814711606</td><td>7/12/2011</td><td>124</td><td>154.06</td><td>90.93</td><td>19103.44</td><td>11275.32</td><td>7828.12</td><td>2021-06-07_11:04:50+00:00</td></tr><tr><td>Sub-Saharan Africa</td><td>Cape Verde</td><td>Clothes</td><td>Offline</td><td>H</td><td>8/2/2014</td><td>939825713</td><td>8/19/2014</td><td>4168</td><td>109.28</td><td>35.84</td><td>455479.04</td><td>149381.12</td><td>306097.92</td><td>2021-06-07_11:04:5 ...
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">dbfs:/mnt/amerentst/input/2021-06-07/SalesRecordsDelta.csv
# Row(_c0=&#39;Region&#39;, _c1=&#39;Country&#39;, _c2=&#39;ItemType&#39;, _c3=&#39;SalesChannel&#39;, _c4=&#39;OrderPriority&#39;, _c5=&#39;OrderDate&#39;, _c6=&#39;OrderID&#39;, _c7=&#39;ShipDate&#39;, _c8=&#39;UnitsSold&#39;, _c9=&#39;UnitPrice&#39;, _c10=&#39;UnitCost&#39;, _c11=&#39;TotalRevenue&#39;, _c12=&#39;TotalCost&#39;, _c13=&#39;TotalProfit&#39;)
# +--------------------+-------+--------------------+------------+-------------+---------+---------+---------+---------+---------+--------+------------+---------+-----------+
#                  _c0|    _c1|                 _c2|         _c3|          _c4|      _c5|      _c6|      _c7|      _c8|      _c9|    _c10|        _c11|     _c12|       _c13|
# +--------------------+-------+--------------------+------------+-------------+---------+---------+---------+---------+---------+--------+------------+---------+-----------+
#               Region|Country|            ItemType|SalesChannel|OrderPriority|OrderDate|  OrderID| ShipDate|UnitsSold|UnitPrice|UnitCost|TotalRevenue|TotalCost|TotalProfit|
#                Delhi|  India|           Baby Food|     Offline|            H|5/28/2010|669168005|6/27/2010|     9925|   255.28|  159.42|     2533654|1582243.5|   951410.5|
# Central America a...|Grenada|              Cereal|     Offline|            C|8/22/2012|963881480|9/15/2012|     2804|    205.7|  117.11|    576782.8|328376.44|  248406.36|
#               Europe| Russia|Office Supplies a...|      Online|            L| 5/2/2014|341417157| 5/8/2014|     1779|   651.21|  524.96|  1158502.59|933903.84|  224598.75|
# +--------------------+-------+--------------------+------------+-------------+---------+---------+---------+---------+---------+--------+------------+---------+-----------+
#
# +--------------------+-------+--------------------+------------+-------------+---------+---------+---------+---------+---------+--------+------------+---------+-----------+---------------------+
#                  _c0|    _c1|                 _c2|         _c3|          _c4|      _c5|      _c6|      _c7|      _c8|      _c9|    _c10|        _c11|     _c12|       _c13|last_update_timestamp|
# +--------------------+-------+--------------------+------------+-------------+---------+---------+---------+---------+---------+--------+------------+---------+-----------+---------------------+
#               Region|Country|            ItemType|SalesChannel|OrderPriority|OrderDate|  OrderID| ShipDate|UnitsSold|UnitPrice|UnitCost|TotalRevenue|TotalCost|TotalProfit| 2021-06-07_11:12:...|
#                Delhi|  India|           Baby Food|     Offline|            H|5/28/2010|669168005|6/27/2010|     9925|   255.28|  159.42|     2533654|1582243.5|   951410.5| 2021-06-07_11:12:...|
# Central America a...|Grenada|              Cereal|     Offline|            C|8/22/2012|963881480|9/15/2012|     2804|    205.7|  117.11|    576782.8|328376.44|  248406.36| 2021-06-07_11:12:...|
#               Europe| Russia|Office Supplies a...|      Online|            L| 5/2/2014|341417157| 5/8/2014|     1779|   651.21|  524.96|  1158502.59|933903.84|  224598.75| 2021-06-07_11:12:...|
# +--------------------+-------+--------------------+------------+-------------+---------+---------+---------+---------+---------+--------+------------+---------+-----------+---------------------+
#
# </div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_c0</th><th>_c1</th><th>_c2</th><th>_c3</th><th>_c4</th><th>_c5</th><th>_c6</th><th>_c7</th><th>_c8</th><th>_c9</th><th>_c10</th><th>_c11</th><th>_c12</th><th>_c13</th><th>last_update_timestamp</th></tr></thead><tbody><tr><td>Region</td><td>Country</td><td>ItemType</td><td>SalesChannel</td><td>OrderPriority</td><td>OrderDate</td><td>OrderID</td><td>ShipDate</td><td>UnitsSold</td><td>UnitPrice</td><td>UnitCost</td><td>TotalRevenue</td><td>TotalCost</td><td>TotalProfit</td><td>2021-06-07_11:12:42+00:00</td></tr><tr><td>Delhi</td><td>India</td><td>Baby Food</td><td>Offline</td><td>H</td><td>5/28/2010</td><td>669168005</td><td>6/27/2010</td><td>9925</td><td>255.28</td><td>159.42</td><td>2533654</td><td>1582243.5</td><td>951410.5</td><td>2021-06-07_11:12:42+00:00</td></tr><tr><td>Central America and the Caribbean</td><td>Grenada</td><td>Cereal</td><td>Offline</td><td>C</td><td>8/22/2012</td><td>963881480</td><td>9/15/2012</td><td>2804</td><td>205.7</td><td>117.11</td><td>576782.8</td><td>328376.44</td><td>248406.36</td><td>2021-06-07_11:12:42+00:00</td></tr><tr><td>Europe</td><td>Russia</td><td>Office Supplies and Baby Food</td><td>Online</td><td>L</td><td>5/2/2014</td><td>341417157</td><td>5/8/2014</td><td>1779</td><td>651.21</td><td>524.96</td><td>1158502.59</td><td>933903.84</td><td>224598.75</td><td>2021-06-07_11:12:42+00:00</td></tr></tbody></table></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">dbfs:/mnt/amerentst/input/2021-06-10/Customers/Customer.csv
# Row(_c0=&#39;c_custkey&#39;, _c1=&#39;c_name&#39;, _c2=&#39;c_address&#39;, _c3=&#39;c_city&#39;, _c4=&#39;c_nation&#39;, _c5=&#39;c_region&#39;, _c6=&#39;c_phone&#39;, _c7=&#39;c_mktsegment&#39;)
# +---------+------------------+------------------+----------+---------+-----------+---------------+------------+
#       _c0|               _c1|               _c2|       _c3|      _c4|        _c5|            _c6|         _c7|
# +---------+------------------+------------------+----------+---------+-----------+---------------+------------+
# c_custkey|            c_name|         c_address|    c_city| c_nation|   c_region|        c_phone|c_mktsegment|
#         1|Customer#000000001|        IVhzIApeRb|MOROCCO  0|  MOROCCO|     AFRICA|25-989-741-2988|    BUILDING|
#         2|Customer#000000002|XSTf4,NCwDVaWNe6tE|JORDAN   1|   JORDAN|MIDDLE EAST|23-768-687-3665|  AUTOMOBILE|
#         3|Customer#000000003|           MG9kdTD|ARGENTINA7|ARGENTINA|    AMERICA|11-719-748-3364|  AUTOMOBILE|
#         4|Customer#000000004|           XxVSJsL|EGYPT    4|    EGYPT|MIDDLE EAST|14-128-190-5944|   MACHINERY|
# +---------+------------------+------------------+----------+---------+-----------+---------------+------------+
# only showing top 5 rows
#
# +---------+------------------+--------------------+----------+--------------+-----------+---------------+------------+---------------------+
#       _c0|               _c1|                 _c2|       _c3|           _c4|        _c5|            _c6|         _c7|last_update_timestamp|
td><td>2021-06-11_11:38:19+00:00</td></tr><tr><td>13</td><td>Customer#000000013</td><td>nsXQu0oVjD7PM6</td><td>CANADA   8</td><td>CANADA</td><td>AMERICA</td><td>13-761-547-5974</td><td>BUILDING</td><td>2021-06-11_11:38:19+00:00</td></tr><tr><td>14</td><td>Customer#000000014</td><td>KXkletMlL</td><td>ARGENTINA0</td><td>ARGENTINA</td><td>AMERICA</td><td>11-845-129-3851</td><td>FURNITURE</td><td>2021-06-11_11:38:19+00:00</td></tr><tr><td>15</td><td>Customer#000000015</td><td>YtWggXoOLdwdo7b0y,BZaGU</td><td>UNITED KI0</td><td>UNITED KINGDOM</td><td>EUROPE</td><td>33-687-542-7601</td><td>HOUSEHOLD</td><td>2021-06-11_11:38:19+00:00</td></tr><tr><td>16</td><td>Customer#000000016</td><td>cYiaeMLZSMA</td><td>IRAN     5</td><td>IRAN</td><td>MIDDLE EAST</td><td>20-781-609-3107</td><td>FURNITURE</td><td>2021-06-11_11:38:19+00:00</td></tr><tr><td>17</td><td>Customer#000000017</td><td>izrh 6jdqtp2eqdtbkswDD8</td><td>BRAZIL   6</td><td>BRAZIL</td><td>AMERICA</td><td>12-970-682-3487</td><td>AUTOMOBILE</td><td>2021-06-11_11:38:19+00:00</td></tr><tr><td>18</td><td>Customer#000000018</td><td>3txGO AiuFux3zT</td><td>FRANCE   0</td><td>FRANCE</td><td>EUROPE</td><td>16-155-215-1315</td><td>BUILDING</td><td>2021-06-11_11:38:19+ ...
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">dbfs:/mnt/amerentst/input/2021-06-10/Orders/Orders.csv
# Row(_c0=&#39;lo_orderkey&#39;, _c1=&#39;lo_linenumber&#39;, _c2=&#39;lo_custkey&#39;, _c3=&#39;lo_partkey&#39;, _c4=&#39;lo_suppkey&#39;, _c5=&#39;lo_orderdatec&#39;, _c6=&#39;lo_orderpriority&#39;, _c7=&#39;lo_shippriority&#39;, _c8=&#39;lo_quantity&#39;, _c9=&#39;lo_extendedprice&#39;, _c10=&#39;lo_ordertotalprice&#39;, _c11=&#39;lo_discount&#39;, _c12=&#39;lo_revenue&#39;, _c13=&#39;lo_supplycost&#39;, _c14=&#39;lo_tax&#39;, _c15=&#39;lo_commitdate&#39;, _c16=&#39;lo_shipmode&#39;)
# +-----------+-------------+----------+----------+----------+-------------+----------------+---------------+-----------+----------------+------------------+-----------+----------+-------------+--------+-------------+-----------+
#         _c0|          _c1|       _c2|       _c3|       _c4|          _c5|             _c6|            _c7|        _c8|             _c9|              _c10|       _c11|      _c12|         _c13|    _c14|         _c15|       _c16|
# +-----------+-------------+----------+----------+----------+-------------+----------------+---------------+-----------+----------------+------------------+-----------+----------+-------------+--------+-------------+-----------+
# lo_orderkey|lo_linenumber|lo_custkey|lo_partkey|lo_suppkey|lo_orderdatec|lo_orderpriority|lo_shippriority|lo_quantity|lo_extendedprice|lo_ordertotalprice|lo_discount|lo_revenue|lo_supplycost|  lo_tax|lo_commitdate|lo_shipmode|
#   461861986|            2|        10|    288307|    925186|     3-MEDIUM|               0|             27|    3497283|        16378273|                10|    3147554|     77717|            3|19930207|         SHIP|       null|
#   126233123|            4|   1056481|    152540|     76822|     3-MEDIUM|               0|              8|    1274032|        19991966|                 5|    1210330|     95552|            3|19930214|         RAIL|       null|
#   575567141|            2|   2101513|     27942|    521243|     1-URGENT|               0|             29|    5422826|        17550309|                10|    4880543|    112196|            4|19930228|          AIR|       null|
#   461861986|            1|        10|    759939|    688757|     3-MEDIUM|               0|             27|    5397030|        16378273|                 7|    5019237|    119934|            2|19930226|          FOB|       null|
# +-----------+-------------+----------+----------+----------+-------------+----------------+---------------+-----------+----------------+------------------+-----------+----------+-------------+--------+-------------+-----------+
# only showing top 5 rows
#
# +-----------+-------------+----------+----------+----------+-------------+----------------+---------------+-----------+----------------+------------------+-----------+----------+-------------+--------+-------------+-----------+---------------------+
#         _c0|          _c1|       _c2|       _c3|       _c4|          _c5|             _c6|            _c7|        _c8|             _c9|              _c10|       _c11|      _c12|         _c13|    _c14|         _c15|       _c16|last_update_timestamp|
# +-----------+-------------+----------+----------+----------+-------------+----------------+---------------+-----------+----------------+------------------+-----------+----------+-------------+--------+-------------+-----------+---------------------+
# lo_orderkey|lo_linenumber|lo_custkey|lo_partkey|lo_suppkey|lo_orderdatec|lo_orderpriority|lo_shippriority|lo_quantity|lo_extendedprice|lo_ordertotalprice|lo_discount|lo_revenue|lo_supplycost|  lo_tax|lo_commitdate|lo_shipmode| 2021-06-11_11:54:...|
#   461861986|            2|        10|    288307|    925186|     3-MEDIUM|               0|             27|    3497283|        16378273|                10|    3147554|     77717|            3|19930207|         SHIP|       null| 2021-06-11_11:54:...|
#   126233123|            4|   1056481|    152540|     76822|     3-MEDIUM|               0|              8|    1274032|        19991966|                 5|    1210330|     95552|            3|19930214|         RAIL|       null| 2021-06-11_11:54:...|
#   575567141|            2|   2101513|     27942|    521243|     1-URGENT|               0|             29|    5422826|        17550309|                10|    4880543|    112196|            4|19930228|          AIR|       null| 2021-06-11_11:54:...|
#   461861986|            1|        10|    759939|    688757|     3-MEDIUM|               0|             27|    5397030|        16378273|                 7|    5019237|    119934|            2|19930226|          FOB|       null| 2021-06-11_11:54:...|
#   437920512|            2|   1056493|    827108|    173085|  4-NOT SPECI|               0|              0|          0|               0|                 0|          0|     62103|            6|19930228|         RAIL|       null| 2021-06-11_11:54:...|
#   575567141|            1|   2101513|    598681|    292767|     1-URGENT|               0|             40|    7118640|        17550309|                 0|    7118640|    106779|            8|19930313|         MAIL|       null| 2021-06-11_11:54:...|
#   105564354|            5|        17|    508423|    592258|  4-NOT SPECI|               0|              0|          0|               0|                 9|          0|     85884|            4|19930216|         MAIL|       null| 2021-06-11_11:54:...|
#   437920512|            7|   1056493|    722259|     21615|  4-NOT SPECI|               0|              0|          0|               0|                 0|          0|     76873|            6|19930223|          FOB|       null| 2021-06-11_11:54:...|
#   134129602|            3|   2101517|    962144|    818848|  4-NOT SPECI|               0|              0|          0|               0|                 9|          0|     72366|            8|19930205|          AIR|       null| 2021-06-11_11:54:...|
#   105564354|            7|        17|    487957|    706811|  4-NOT SPECI|               0|              0|          0|               0|                 0|          0|    116695|            8|19930306|          AIR|       null| 2021-06-11_11:54:...|
# ...
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">dbfs:/mnt/amerentst/output/valid/_delta_log/00000000000000000002.json
# Row(_c0=&#39;{&#34;commitInfo&#34;:{&#34;timestamp&#34;:1623159597006&#39;, _c1=&#39;&#34;userId&#34;:&#34;5852003715329243&#34;&#39;, _c2=&#39;&#34;userName&#34;:&#34;sinautiyal@deloitte.com&#34;&#39;, _c3=&#39;&#34;operation&#34;:&#34;MERGE&#34;&#39;, _c4=&#39;&#34;operationParameters&#34;:{&#34;predicate&#34;:&#34;(master.`pksha2` = cdc.`pksha2`)&#34;&#39;, _c5=&#39;&#34;matchedPredicates&#34;:&#34;[{\\&#34;predicate\\&#34;:\\&#34;(master.`active_flag` = 1)\\&#34;&#39;, _c6=&#39;\\&#34;actionType\\&#34;:\\&#34;update\\&#34;}]&#34;&#39;, _c7=&#39;&#34;notMatchedPredicates&#34;:&#34;[{\\&#34;actionType\\&#34;:\\&#34;insert\\&#34;}]&#34;}&#39;, _c8=&#39;&#34;notebook&#34;:{&#34;notebookId&#34;:&#34;1154893030432323&#34;}&#39;, _c9=&#39;&#34;clusterId&#34;:&#34;0608-051139-shuts238&#34;&#39;, _c10=&#39;&#34;readVersion&#34;:1&#39;, _c11=&#39;&#34;isolationLevel&#34;:&#34;WriteSerializable&#34;&#39;, _c12=&#39;&#34;isBlindAppend&#34;:false&#39;, _c13=&#39;&#34;operationMetrics&#34;:{&#34;numTargetRowsCopied&#34;:&#34;98&#34;&#39;, _c14=&#39;&#34;numTargetRowsDeleted&#34;:&#34;0&#34;&#39;, _c15=&#39;&#34;numTargetFilesAdded&#34;:&#34;2&#34;&#39;, _c16=&#39;&#34;executionTimeMs&#34;:&#34;20041&#34;&#39;, _c17=&#39;&#34;numTargetRowsInserted&#34;:&#34;3&#34;&#39;, _c18=&#39;&#34;scanTimeMs&#34;:&#34;6361&#34;&#39;, _c19=&#39;&#34;numTargetRowsUpdated&#34;:&#34;2&#34;&#39;, _c20=&#39;&#34;numOutputRows&#34;:&#34;103&#34;&#39;, _c21=&#39;&#34;numTargetChangeFilesAdded&#34;:&#34;0&#34;&#39;, _c22=&#39;&#34;numSourceRows&#34;:&#34;5&#34;&#39;, _c23=&#39;&#34;numTargetFilesRemoved&#34;:&#34;1&#34;&#39;, _c24=&#39;&#34;rewriteTimeMs&#34;:&#34;13426&#34;}}}&#39;)
# +--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
#                  _c0|                 _c1|                 _c2|                 _c3|                 _c4|                 _c5|                 _c6|                 _c7|                 _c8|                 _c9|                _c10|                _c11|                _c12|                _c13|                _c14|                _c15|                _c16|                _c17|                _c18|                _c19|                _c20|                _c21|                _c22|                _c23|                _c24|
# +--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# {&#34;commitInfo&#34;:{&#34;t...|&#34;userId&#34;:&#34;5852003...|&#34;userName&#34;:&#34;sinau...| &#34;operation&#34;:&#34;MERGE&#34;|&#34;operationParamet...|&#34;matchedPredicate...|\&#34;actionType\&#34;:\&#34;...|&#34;notMatchedPredic...|&#34;notebook&#34;:{&#34;note...|&#34;clusterId&#34;:&#34;0608...|     &#34;readVersion&#34;:1|&#34;isolationLevel&#34;:...|&#34;isBlindAppend&#34;:f...|&#34;operationMetrics...|&#34;numTargetRowsDel...|&#34;numTargetFilesAd...|&#34;executionTimeMs&#34;...|&#34;numTargetRowsIns...| &#34;scanTimeMs&#34;:&#34;6361&#34;|&#34;numTargetRowsUpd...|&#34;numOutputRows&#34;:&#34;...|&#34;numTargetChangeF...| &#34;numSourceRows&#34;:&#34;5&#34;|&#34;numTargetFilesRe...|&#34;rewriteTimeMs&#34;:&#34;...|
# {&#34;remove&#34;:{&#34;path&#34;...|&#34;deletionTimestam...|   &#34;dataChange&#34;:true|&#34;extendedFileMeta...|&#34;partitionValues&#34;...|      &#34;size&#34;:25219}}|                null|                null|                null|                null|                null|                null|                null|                null|                null|                null|                null|                null|                null|                null|                null|                null|                null|                null|                null|
# {&#34;add&#34;:{&#34;path&#34;:&#34;a...|&#34;partitionValues&#34;...|         &#34;size&#34;:6065|&#34;modificationTime...|   &#34;dataChange&#34;:true|&#34;stats&#34;:&#34;{\&#34;numRe...|\&#34;minValues\&#34;:{\&#34;...|\&#34;Country\&#34;:\&#34;Gre...|\&#34;ItemType\&#34;:\&#34;Ce...|\&#34;SalesChannel\&#34;:...|\&#34;OrderPriority\&#34;...|\&#34;OrderDate\&#34;:\&#34;5...|\&#34;OrderID\&#34;:34141...|\&#34;ShipDate\&#34;:\&#34;5/...|  \&#34;UnitsSold\&#34;:1779| \&#34;UnitPrice\&#34;:205.7| \&#34;UnitCost\&#34;:117.11|\&#34;TotalRevenue\&#34;:...|\&#34;TotalCost\&#34;:328...|\&#34;TotalProfit\&#34;:2...|\&#34;business_date\&#34;...|\&#34;current_ts\&#34;:\&#34;...|\&#34;update_ts\&#34;:\&#34;2...|\&#34;pksha2\&#34;:\&#34;6ab6...|\&#34;sha2\&#34;:\&#34;bc7dda...|
# {&#34;add&#34;:{&#34;path&#34;:&#34;a...|&#34;partitionValues&#34;...|        &#34;size&#34;:25198|&#34;modificationTime...|   &#34;dataChange&#34;:true|&#34;stats&#34;:&#34;{\&#34;numRe...|\&#34;minValues\&#34;:{\&#34;...|\&#34;Country\&#34;:\&#34;Alb...|\&#34;ItemType\&#34;:\&#34;Ba...|\&#34;SalesChannel\&#34;:...|\&#34;OrderPriority\&#34;...|\&#34;OrderDate\&#34;:\&#34;1...|\&#34;OrderID\&#34;:11460...|\&#34;ShipDate\&#34;:\&#34;1/...|   \&#34;UnitsSold\&#34;:124|  \&#34;UnitPrice\&#34;:9.33|   \&#34;UnitCost\&#34;:6.92|\&#34;TotalRevenue\&#34;:...|\&#34;TotalCost\&#34;:361...|\&#34;TotalProfit\&#34;:1...|\&#34;business_date\&#34;...|\&#34;current_ts\&#34;:\&#34;...|\&#34;update_ts\&#34;:\&#34;9...|\&#34;pksha2\&#34;:\&#34;0406...|\&#34;sha2\&#34;:\&#34;00512b...|
# +--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
#
# +--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+---------------------+
#                  _c0|                 _c1|                 _c2|                 _c3|                 _c4|                 _c5|                 _c6|                 _c7|                 _c8|                 _c9|                _c10|                _c11|                _c12|                _c13|                _c14|                _c15|                _c16|                _c17|
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_c0</th><th>_c1</th><th>_c2</th><th>_c3</th><th>_c4</th><th>_c5</th><th>_c6</th><th>_c7</th><th>_c8</th><th>_c9</th><th>_c10</th><th>_c11</th><th>_c12</th><th>_c13</th><th>_c14</th><th>_c15</th><th>_c16</th><th>_c17</th><th>_c18</th><th>_c19</th><th>_c20</th><th>_c21</th><th>_c22</th><th>_c23</th><th>_c24</th><th>last_update_timestamp</th></tr></thead><tbody><tr><td>{"commitInfo":{"timestamp":1623159597006</td><td>"userId":"5852003715329243"</td><td>"userName":"sinautiyal@deloitte.com"</td><td>"operation":"MERGE"</td><td>"operationParameters":{"predicate":"(master.`pksha2` = cdc.`pksha2`)"</td><td>"matchedPredicates":"[{\"predicate\":\"(master.`active_flag` = 1)\"</td><td>\"actionType\":\"update\"}]"</td><td>"notMatchedPredicates":"[{\"actionType\":\"insert\"}]"}</td><td>"notebook":{"notebookId":"1154893030432323"}</td><td>"clusterId":"0608-051139-shuts238"</td><td>"readVersion":1</td><td>"isolationLevel":"WriteSerializable"</td><td>"isBlindAppend":false</td><td>"operationMetrics":{"numTargetRowsCopied":"98"</td><td>"numTargetRowsDeleted":"0"</td><td>"numTargetFilesAdded":"2"</td><td>"executionTimeMs":"20041"</td><td>"numTargetRowsInserted":"3"</td><td>"scanTimeMs":"6361"</td><td>"numTargetRowsUpdated":"2"</td><td>"numOutputRows":"103"</td><td>"numTargetChangeFilesAdded":"0"</td><td>"numSourceRows":"5"</td><td>"numTargetFilesRemoved":"1"</td><td>"rewriteTimeMs":"13426"}}}</td><td>2021-06-08_13:39:58+00:00</td></tr><tr><td>{"remove":{"path":"active_flag=1/part-00000-f4ed61e7-76a5-4b3f-8c89-5130285afc9c.c000.snappy.parquet"</td><td>"deletionTimestamp":1623159597005</td><td>"dataChange":true</td><td>"extendedFileMetadata":true</td><td>"partitionValues":{"active_flag":"1"}</td><td>"size":25219}}</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>2021-06-08_13:39:58+00:00</td></tr><tr><td>{"add":{"path":"active_flag=0/part-00000-8053764a-1e79-43b5-a201-5f7b9ff9e0a6.c000.snappy.parquet"</td><td>"partitionValues":{"active_flag":"0"}</td><td>"size":6065</td><td>"modificationTime":1623159595000</td><td>"dataChange":true</td><td>"stats":"{\"numRecords\":2</td><td>\"minValues\":{\"Region\":\"Central America and the Caribbea\"</td><td>\"Country\":\"Grenada\"</td><td>\"ItemType\":\"Cereal\"</td><td>\"SalesChannel\":\"Offline\"</td><td>\"OrderPriority\":\"C\"</td><td>\"OrderDate\":\"5/2/2014\"</td><td>\"OrderID\":341417157</td><td>\"ShipDate\":\"5/8/2014\"</td><td>\"UnitsSold\":1779</td><td>\"UnitPrice\":205.7</td><td>\"UnitCost\":117.11</td><td>\"TotalRevenue\":576782.8</td><td>\"TotalCost\":328376.44</td><td>\"TotalProfit\":224598.75</td><td>\"business_date\":\"2021-06-06\"</td><td>\"current_ts\":\"2021-06-08 13:37:30\"</td><td>\"update_ts\":\"2021-06-08 13:39:24\"</td><td>\"pksha2\":\"6ab6cf2e1d517a1937fa61b698630bce\"</td><td>\"sha2\":\"bc7dda9d03fdb7c24576ebb4778d3bc2\"}</td><td>2021-06-08_13:39:58+00:00</td></tr><tr><td>{"add":{"path":"active_flag=1/part-00000-09c5cf84-9527-4234-a59d-e789a2395d41.c000.snappy.parquet"</td><td>"partitionValues":{"active_flag":"1"}</td><td>"size":25198</td><td>"modificationTime":1623159597000</td><td>"dataChange":true</td><td>"stats":"{\"numRecords\":101</td><td>\"minValues\":{\"Region\":\"Asia\"</td><td>\"Country\":\"Albania\"</td><td>\"ItemType\":\"Baby Food\"</td><td>\"SalesChannel\":\"Offline\"</td><td>\"OrderPriority\":\"C\"</td><td>\"OrderDate\":\"1/11/2012\"</td><td>\"OrderID\":114606559</td><td>\"ShipDate\":\"1/13/2012\"</td><td>\"UnitsSold\":124</td><td>\"UnitPrice\":9.33</td><td>\"UnitCost\":6.92</td><td>\"TotalRevenue\":4870.26</td><td>\"TotalCost\":3612.24</td><td>\"TotalProfit\":1258.02</td><td>\"business_date\":\"2021-06-06\"</td><td>\"current_ts\":\"2021-06-08 13:37:30\"</ ...
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">dbfs:/mnt/amerentst/reject/salesRecords/salesRecords.csv/part-00000-tid-6287785740859178763-8afecd2c-e5f1-45bf-8947-f67c5271efd2-358-1-c000.csv
# Row(_c0=&#39;Region&#39;, _c1=&#39;Country&#39;, _c2=&#39;ItemType&#39;, _c3=&#39;SalesChannel&#39;, _c4=&#39;OrderPriority&#39;, _c5=&#39;OrderDate&#39;, _c6=&#39;OrderID&#39;, _c7=&#39;ShipDate&#39;, _c8=&#39;UnitsSold&#39;, _c9=&#39;UnitPrice&#39;, _c10=&#39;UnitCost&#39;, _c11=&#39;TotalRevenue&#39;, _c12=&#39;TotalCost&#39;, _c13=&#39;TotalProfit&#39;, _c14=&#39;ErrorDesc&#39;)
# +------+-------+--------+------------+-------------+---------+-------+--------+---------+---------+--------+------------+---------+-----------+---------+
#    _c0|    _c1|     _c2|         _c3|          _c4|      _c5|    _c6|     _c7|      _c8|      _c9|    _c10|        _c11|     _c12|       _c13|     _c14|
# +------+-------+--------+------------+-------------+---------+-------+--------+---------+---------+--------+------------+---------+-----------+---------+
# Region|Country|ItemType|SalesChannel|OrderPriority|OrderDate|OrderID|ShipDate|UnitsSold|UnitPrice|UnitCost|TotalRevenue|TotalCost|TotalProfit|ErrorDesc|
# +------+-------+--------+------------+-------------+---------+-------+--------+---------+---------+--------+------------+---------+-----------+---------+
#
# +------+-------+--------+------------+-------------+---------+-------+--------+---------+---------+--------+------------+---------+-----------+---------+---------------------+
#    _c0|    _c1|     _c2|         _c3|          _c4|      _c5|    _c6|     _c7|      _c8|      _c9|    _c10|        _c11|     _c12|       _c13|     _c14|last_update_timestamp|
# +------+-------+--------+------------+-------------+---------+-------+--------+---------+---------+--------+------------+---------+-----------+---------+---------------------+
# Region|Country|ItemType|SalesChannel|OrderPriority|OrderDate|OrderID|ShipDate|UnitsSold|UnitPrice|UnitCost|TotalRevenue|TotalCost|TotalProfit|ErrorDesc| 2021-06-08_13:39:...|
# +------+-------+--------+------------+-------------+---------+-------+--------+---------+---------+--------+------------+---------+-----------+---------+---------------------+
#
# </div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_c0</th><th>_c1</th><th>_c2</th><th>_c3</th><th>_c4</th><th>_c5</th><th>_c6</th><th>_c7</th><th>_c8</th><th>_c9</th><th>_c10</th><th>_c11</th><th>_c12</th><th>_c13</th><th>_c14</th><th>last_update_timestamp</th></tr></thead><tbody><tr><td>Region</td><td>Country</td><td>ItemType</td><td>SalesChannel</td><td>OrderPriority</td><td>OrderDate</td><td>OrderID</td><td>ShipDate</td><td>UnitsSold</td><td>UnitPrice</td><td>UnitCost</td><td>TotalRevenue</td><td>TotalCost</td><td>TotalProfit</td><td>ErrorDesc</td><td>2021-06-08_13:39:31+00:00</td></tr></tbody></table></div>
